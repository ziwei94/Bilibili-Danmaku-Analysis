# %%
import pandas as pd
data = pd.read_excel(r'D:\戴师兄\python第二讲资料\1、系统认识数据分析.xlsx',
                    converters = {'uid':str}
                    )
data
# Out:
#                        id  progress                  content       ctime  \
# 0       53766889040208384      2691  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！  1629643402
# 1       53783364377004544      9193                    DNA动了  1629674826
# 2       53783376819848704     23017                     大制作啊  1629674850
# 3       53788075865425920     31033               好家伙 我直接好家伙  1629683812
# 4       53811230195500032     68093                      大制作  1629727976
# ...                   ...       ...                      ...         ...
# 2121  1218810663133506304   1658114              礼貌提问，大古是啥..  1672384753
# 2122  1220839829835662592   1499315                   农学实名观看  1672626648
# 2123  1221739920041784064   1734608                   留下一个爪印  1672733947
# 2124  1221887180755147776   1759777                   扎实的第一步  1672751502
# 2125  1222310337660096000   1615499                  信息与计算科学  1672801946
#
#                        uid
# 0      4658843910516903647
# 1     -5089316151886879487
# ...

# %%
data['id'] = data['id'].astype(str)

# %%
data.to_excel('test excel.xlsx',index=False)

# %%
data
# Out:
#                        id  progress                  content       ctime  \
# 0       53766889040208384      2691  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！  1629643402
# 1       53783364377004544      9193                    DNA动了  1629674826
# 2       53783376819848704     23017                     大制作啊  1629674850
# 3       53788075865425920     31033               好家伙 我直接好家伙  1629683812
# 4       53811230195500032     68093                      大制作  1629727976
# ...                   ...       ...                      ...         ...
# 2121  1218810663133506304   1658114              礼貌提问，大古是啥..  1672384753
# 2122  1220839829835662592   1499315                   农学实名观看  1672626648
# 2123  1221739920041784064   1734608                   留下一个爪印  1672733947
# 2124  1221887180755147776   1759777                   扎实的第一步  1672751502
# 2125  1222310337660096000   1615499                  信息与计算科学  1672801946
#
#                        uid
# 0      4658843910516903647
# 1     -5089316151886879487
# ...

# %%
data[['id','content','uid']]
# Out:
#                        id                  content                   uid
# 0       53766889040208384  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！   4658843910516903647
# 1       53783364377004544                    DNA动了  -5089316151886879487
# 2       53783376819848704                     大制作啊  -5089316151886879487
# 3       53788075865425920               好家伙 我直接好家伙  -6460990597571269883
# 4       53811230195500032                      大制作   8879111121911466217
# ...                   ...                      ...                   ...
# 2121  1218810663133506304              礼貌提问，大古是啥..   3205881671998110354
# 2122  1220839829835662592                   农学实名观看  -2040096988083157546
# 2123  1221739920041784064                   留下一个爪印   4435509291488926332
# 2124  1221887180755147776                   扎实的第一步   4633711017283044897
# 2125  1222310337660096000                  信息与计算科学  -5175298829888224618
#
# [2126 rows x 3 columns]

# %%
data2 = pd.read_excel(r'D:\戴师兄\python第二讲资料\2、EXCEL基础操作.xlsx',
                      converters={'id':str,'uid':str})
data2
# Out:
#                         id  progress         content       ctime  \
# 0        53806112870839808      6260           第一条弹幕  1629718215
# 1        53806933426753536     10420            来了，棒  1629719780
# 2        53807166301780480     31344   3个小时 1.0是2个小时  1629720225
# 3        53807435106465280     30510           第九条弹幕  1629720737
# 4        53811722117039616      6199            时长感人  1629728914
# ...                    ...       ...             ...         ...
# 12543  1218217237174119424  12020175               5  1672314011
# 12544  1221471971259422976  12013829  完结撒花！！！谢谢师兄！！！  1672702005
# 12545  1221472029442967808  12021000               5  1672702012
# 12546  1221890371571986432  12010022     为自己鼓掌，为师兄鼓掌  1672751883
# 12547  1221891095576086784  12021000               5  1672751969
#
#                         uid
# 0      -5524725689125822280
# 1                       NaN
# 2       4892315397097361368
# 3       2377566476259591671
# 4       6716553225725719128
# ...

# %%
data
# Out:
#                        id  progress                  content       ctime  \
# 0       53766889040208384      2691  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！  1629643402
# 1       53783364377004544      9193                    DNA动了  1629674826
# 2       53783376819848704     23017                     大制作啊  1629674850
# 3       53788075865425920     31033               好家伙 我直接好家伙  1629683812
# 4       53811230195500032     68093                      大制作  1629727976
# ...                   ...       ...                      ...         ...
# 2121  1218810663133506304   1658114              礼貌提问，大古是啥..  1672384753
# 2122  1220839829835662592   1499315                   农学实名观看  1672626648
# 2123  1221739920041784064   1734608                   留下一个爪印  1672733947
# 2124  1221887180755147776   1759777                   扎实的第一步  1672751502
# 2125  1222310337660096000   1615499                  信息与计算科学  1672801946
#
#                        uid
# 0      4658843910516903647
# 1     -5089316151886879487
# ...

# %%
concat_demo=pd.concat([data,data2], axis=0)
concat_demo
# Out:
#                         id  progress                  content       ctime  \
# 0        53766889040208384      2691  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！  1629643402
# 1        53783364377004544      9193                    DNA动了  1629674826
# 2        53783376819848704     23017                     大制作啊  1629674850
# 3        53788075865425920     31033               好家伙 我直接好家伙  1629683812
# 4        53811230195500032     68093                      大制作  1629727976
# ...                    ...       ...                      ...         ...
# 12543  1218217237174119424  12020175                        5  1672314011
# 12544  1221471971259422976  12013829           完结撒花！！！谢谢师兄！！！  1672702005
# 12545  1221472029442967808  12021000                        5  1672702012
# 12546  1221890371571986432  12010022              为自己鼓掌，为师兄鼓掌  1672751883
# 12547  1221891095576086784  12021000                        5  1672751969
#
#                         uid
# 0       4658843910516903647
# ...

# %%
user_level = pd.read_excel(r'D:\戴师兄\python第二讲资料\user_level.xlsx',
                          converters={'uid':str})
user_level
# Out:
#       level                   uid
# 0         5   4658843910516903647
# 1         0  -5089316151886879487
# 2         6  -6460990597571269883
# 3         6   8879111121911466217
# 4         4   8005564574121047830
# ...     ...                   ...
# 8387      0   8789285327467475495
# 8388      6  -3706436855316824035
# 8389      0  -2335781148162268958
# 8390      5   2218640609761978448
# 8391      4   6689174160540423840
#
# [8392 rows x 2 columns]

# %%
pd.merge(concat_demo,user_level,how='inner',on='uid')
# Out:
#                         id  progress                  content       ctime  \
# 0        53766889040208384      2691  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！  1629643402
# 1        54982927380083200   4137203                        2  1631962811
# 2        53783364377004544      9193                    DNA动了  1629674826
# 3        53783376819848704     23017                     大制作啊  1629674850
# 4        53850829626031616      1931                       打卡  1629803506
# ...                    ...       ...                      ...         ...
# 14412  1210998817818951168  11995664        不容易啊 谢谢师兄 谢谢自己的坚持  1671453508
# 14413  1210999015647360256  12019577                        5  1671453532
# 14414  1213209680135010560  12020000                        5  1671717064
# 14415  1214626257271038208  12019112                        5  1671885933
# 14416  1218217237174119424  12020175                        5  1672314011
#
#                         uid  level
# 0       4658843910516903647      5
# ...

# %%
data
# Out:
#                        id  progress                  content       ctime  \
# 0       53766889040208384      2691  这熟悉的bgm让人灵魂颤抖，向敌军进攻，冲啊！  1629643402
# 1       53783364377004544      9193                    DNA动了  1629674826
# 2       53783376819848704     23017                     大制作啊  1629674850
# 3       53788075865425920     31033               好家伙 我直接好家伙  1629683812
# 4       53811230195500032     68093                      大制作  1629727976
# ...                   ...       ...                      ...         ...
# 2121  1218810663133506304   1658114              礼貌提问，大古是啥..  1672384753
# 2122  1220839829835662592   1499315                   农学实名观看  1672626648
# 2123  1221739920041784064   1734608                   留下一个爪印  1672733947
# 2124  1221887180755147776   1759777                   扎实的第一步  1672751502
# 2125  1222310337660096000   1615499                  信息与计算科学  1672801946
#
#                        uid
# 0      4658843910516903647
# 1     -5089316151886879487
# ...

# %%
data.sort_values('uid')
# Out:
#                        id  progress                    content       ctime  \
# 933     56531329726263808    831133                   有什么证可以考？  1634916154
# 954     57848773333896704    813094               43个人诶.都不睡觉的吗  1637428978
# 1947  1131096167019724032   1770159                          5  1661928370
# 1832  1065329384224822528   1592185                       财务=1  1654088359
# 575     59422358457521664    494197                额，这是0基础课程么？  1640430354
# ...                   ...       ...                        ...         ...
# 1709   999879611859039232   1536559                      谢谢你泰罗  1646286138
# 1751  1021695826524661760   1760107           职场人要时刻提升自己的核心竞争路  1648886833
# 1855  1086257688322523648   1485647                   现在有多少人在看  1656583207
# 1856  1086258441384824576   1575461  我就想学习一下工具的使用，工具的使用要学到什么程度  1656583297
# 2063  1150635909893407488   1777634                      66666  1664257689
#
#                        uid
# 933   -1024376498162345291
# ...

# %%
import pygwalker as pw

# %%
pw.walk(data)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-00060f8b8616aa54iC3Nq7TYtagEh9m4" style="height: auto">\n    <head>…
